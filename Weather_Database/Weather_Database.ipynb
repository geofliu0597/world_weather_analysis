# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7eb9c8f29d7cdcffb1bf48e496b710bb

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
cities
# Out:
# ['puerto ayora',
#  'norman wells',
#  'yulara',
#  'khani',
#  'vreed en hoop',
#  'barrow',
#  'arraial do cabo',
#  'hasaki',
#  'malanje',
#  'georgetown',
#  'palabuhanratu',
#  'jiutai',
#  'kushiro',
#  'new norfolk',
#  'faanui',
#  'huilong',
#  'saldanha',
#  'taolanaro',
#  'bolungarvik',
#  'micheweni',
#  'richards bay',
#  'changtu',
#  'constitucion',
#  'sorland',
#  'saskylakh',
#  'punta arenas',
#  'ketchikan',
#  'limbang',
#  'wulanhaote',
#  'atuona',
#  'lenine',
#  'hobart',
#  'rikitea',
#  'bambous virieux',
#  'mataura',
#  'mar del plata',
#  'albany',
#  'trinidad',
#  'havre-saint-pierre',
#  'los llanos de aridane',
#  'trenggalek',
#  'sakakah',
#  'pevek',
#  'lompoc',
#  'hilo',
#  'cabedelo',
#  'saint-georges',
#  'great yarmouth',
#  'aflu',
#  'wageningen',
#  'severo-kurilsk',
#  'trairi',
#  'toora-khem',
#  'castro',
#  'buta',
#  'shimoda',
#  'ancud',
#  'port elizabeth',
#  'salinopolis',
#  'busselton',
#  'manadhoo',
#  'praya',
#  'pangnirtung',
#  'viytivka',
#  'paamiut',
#  'meulaboh',
#  'lebu',
#  'muros',
#  'shahr-e kord',
#  'kahului',
#  'ormara',
#  'ahome',
#  'ouadda',
#  'kapaa',
#  'ahuimanu',
#  'makueni',
#  'altay',
#  'puerto madero',
#  'avarua',
#  'vaini',
#  'karkaralinsk',
#  'butaritari',
#  'belushya guba',
#  'dunedin',
#  'pozo colorado',
#  'xichang',
#  'codrington',
#  'ushuaia',
#  'sentyabrskiy',
#  'asyut',
#  'cururupu',
#  'naryan-mar',
#  'mangrol',
#  'saint-augustin',
#  'palu',
#  'jamestown',
#  'teknaf',
#  'waingapu',
#  'nesebar',
#  'victoria point',
#  'grand river south east',
#  'marcona',
#  'avera',
#  'terney',
#  'solnechnyy',
#  'conde',
#  'mys shmidta',
#  'east london',
#  'le port',
#  'dingle',
#  'souillac',
#  'alanya',
#  'honiara',
#  'kaifeng',
#  'tsihombe',
#  'ponta do sol',
#  'cape town',
#  'hermanus',
#  'miranorte',
#  'quesnel',
#  'qaanaaq',
#  'port alfred',
#  'burhanpur',
#  'penzance',
#  'vila franca do campo',
#  'key west',
#  'buala',
#  'nizhneyansk',
#  'attawapiskat',
#  'nioki',
#  'kizukuri',
#  'bandarbeyla',
#  'kilifi',
#  'upernavik',
#  'illoqqortoormiut',
#  'catabola',
#  'pangkalanbuun',
#  'blahodatne',
#  'kimberley',
#  'narsaq',
#  'les cayes',
#  'cabo san lucas',
#  'egvekinot',
#  'amahai',
#  'mao',
#  'okhotsk',
#  'walvis bay',
#  'tiksi',
#  'bluff',
#  'almaznyy',
#  'kruisfontein',
#  'guerrero negro',
#  'kearney',
#  'tynda',
#  'tehachapi',
#  'fort nelson',
#  'ghanzi',
#  'sumbe',
#  'valparaiso',
#  'cockburn town',
#  'bredasdorp',
#  'mahibadhoo',
#  'tasiilaq',
#  'elizabeth city',
#  'longyearbyen',
#  'victor harbor',
#  'kirakira',
#  'plettenberg bay',
#  'fortuna',
#  'kyshtovka',
#  'ambon',
#  'barentsburg',
#  'sioux lookout',
#  'isangel',
#  'japura',
#  'sao joao da barra',
#  'hualmay',
#  'klaksvik',
#  'kodiak',
#  'vaitupu',
#  'rong kwang',
#  'tessalit',
#  'olafsvik',
#  'kavieng',
#  'yellowknife',
#  'halalo',
#  'san patricio',
#  'mahebourg',
#  'nikolskoye',
#  'sola',
#  'neiafu',
#  'borborema',
#  'chuy',
#  'hithadhoo',
#  'anadyr',
#  'srandakan',
#  'luderitz',
#  'puerto penasco',
#  'san cristobal',
#  'saint-philippe',
#  'casian',
#  'bethel',
#  'lavrentiya',
#  'iwanai',
#  'port macquarie',
#  'nome',
#  'scarborough',
#  'sabang',
#  'novorudnyy',
#  'kavaratti',
#  'chokurdakh',
#  'talnakh',
#  'xiaolingwei',
#  'pecos',
#  'torbay',
#  'nioro',
#  'yarim',
#  'amderma',
#  'santa rosa de viterbo',
#  'wampusirpi',
#  'fort-shevchenko',
#  'stabat',
#  'portland',
#  'goderich',
#  'wanxian',
#  'washougal',
#  'pisco',
#  'provideniya',
#  'victoria',
#  'ca mau',
#  'san carlos de bariloche',
#  'stutterheim',
#  'zwedru',
#  'thompson',
#  'litoral del san juan',
#  'esperance',
#  'ilulissat',
#  'yumen',
#  'backa topola',
#  'carnarvon',
#  'ardesen',
#  'olinda',
#  'ruda nad moravou',
#  'santa maria',
#  'baisha',
#  'oranjemund',
#  'ayan',
#  'dudinka',
#  'yokadouma',
#  'puerto escondido',
#  'toamasina',
#  'merauke',
#  'coihaique',
#  'gizo',
#  'saleaula',
#  'laguna',
#  'porvoo',
#  'tateyama',
#  'sitka',
#  'rocha',
#  'alekseyevsk',
#  'grindavik',
#  'rolim de moura',
#  'tirumullaivasal',
#  'santa marta',
#  'antalaha',
#  'horadiz',
#  'katsuura',
#  'kaltasy',
#  'karaul',
#  'traverse city',
#  'ahipara',
#  'sindor',
#  'upington',
#  'auki',
#  'bathsheba',
#  'tobermory',
#  'vostok',
#  'charters towers',
#  'redlands',
#  'krasnoselkup',
#  'port keats',
#  'bordei verde',
#  'garden city',
#  'kashi',
#  'nadym',
#  'lorengau',
#  'clyde river',
#  'pekan',
#  'vestmannaeyjar',
#  'gambela',
#  'cabo rojo',
#  'lyuban',
#  'yarada',
#  'ewa beach',
#  'cidreira',
#  'kharp',
#  'najran',
#  'tuktoyaktuk',
#  'orgun',
#  'launceston',
#  'sinnamary',
#  'bay roberts',
#  'birin',
#  'gornoye loo',
#  'camacha',
#  'balkhash',
#  'sainte-maxime',
#  'kloulklubed',
#  'lucapa',
#  'bronnoysund',
#  'maningrida',
#  'yenagoa',
#  'luena',
#  'lashio',
#  'tuatapere',
#  'korla',
#  'grand gaube',
#  'ambulu',
#  'shiroishi',
#  'fairbanks',
#  'kerema',
#  'manggar',
#  'barra patuca',
#  'hami',
#  'dikson',
#  'kaluga',
#  'half moon bay',
#  'nguiu',
#  'emerald',
#  'rincon',
#  'sa kaeo',
#  'iqaluit',
#  'douentza',
#  'labutta',
#  'saint-denis',
#  'yuli',
#  'sumbawa',
#  'middelburg',
#  'marawi',
#  'adrar',
#  'rusape',
#  'namibe',
#  'sabha',
#  'buraydah',
#  'shache',
#  'ust-bolsheretsk',
#  'necochea',
#  'ribeira grande',
#  'elat',
#  'tanjong sepat',
#  'durango',
#  'niksar',
#  'mezen',
#  'swan hill',
#  'san quintin',
#  'miloslavskoye',
#  'waterloo',
#  'dimitrovgrad',
#  'palmer',
#  'bilma',
#  'uzunkopru',
#  'basudebpur',
#  'alice springs',
#  'oga',
#  'hobyo',
#  'oistins',
#  'mount gambier',
#  'americus',
#  'kutum',
#  'vila velha',
#  'kaitangata',
#  'vryburg',
#  'saint-francois',
#  'mount isa',
#  'soyo',
#  'chernyshevskiy',
#  'newport',
#  'pochutla',
#  'umiray',
#  'coquimbo',
#  'skovorodino',
#  'nago',
#  'lebanon',
#  'bosaso',
#  'campoverde',
#  'harper',
#  'tarudant',
#  'iisalmi',
#  'kuah',
#  'nouadhibou',
#  'rock sound',
#  'porto velho',
#  'nortelandia',
#  'tilichiki',
#  'umm lajj',
#  'puerto carreno',
#  'artyk',
#  'yar-sale',
#  'belaya gora',
#  'airai',
#  'lolua',
#  'ixtapa',
#  'viedma',
#  'komsomolskiy',
#  'kindersley',
#  'abnub',
#  'aracati',
#  'jinchang',
#  'bitkine',
#  'pizarro',
#  'mahadday weyne',
#  'vardo',
#  'contamana',
#  'palmas bellas',
#  'boa vista',
#  'tieli',
#  'ciudad ojeda',
#  'canutama',
#  'rundu',
#  'peniche',
#  'asau',
#  'nanortalik',
#  'acapulco',
#  'zhigansk',
#  'alotau',
#  'baijiantan',
#  'liberty',
#  'tokonou',
#  'san andres',
#  'goundam',
#  'andreyevo',
#  'ponta delgada',
#  'vuktyl',
#  'khasan',
#  'of',
#  'antigonish',
#  'christchurch',
#  'bundibugyo',
#  'namatanai',
#  'khatanga',
#  'novosheshminsk',
#  'nabire',
#  'praia da vitoria',
#  'kathu',
#  'naze',
#  'leningradskiy',
#  'urumqi',
#  'belyy yar',
#  'jalu',
#  'tshane',
#  'nanpara',
#  'berdigestyakh',
#  'vestmanna',
#  'aljezur',
#  'morondava',
#  'san jose',
#  'mareeba',
#  'tual',
#  'springdale',
#  'bengkulu',
#  'hamilton',
#  'kutno',
#  'bastrop',
#  'severodvinsk',
#  'mehamn',
#  'nuuk',
#  'tim',
#  'kindu',
#  'kropotkin',
#  'minuri',
#  'emmen',
#  'jiuquan',
#  'matagami',
#  'kirkwall',
#  'juneau',
#  'cherskiy',
#  'avon park',
#  'gulfport',
#  'praia',
#  'pinheiro machado',
#  'oktyabrskiy',
#  'kansanshi',
#  'port blair',
#  'rawson',
#  'karoi',
#  'peterhead',
#  'touros',
#  'port augusta',
#  'kayiry',
#  'sao filipe',
#  'brae',
#  'westport',
#  'sanary-sur-mer',
#  'mahanje',
#  'aranos',
#  'chivay',
#  'bardiyah',
#  'belmonte',
#  'haibowan',
#  'antibes',
#  'road town',
#  'moerai',
#  'kirsanov',
#  'west wendover',
#  'beringovskiy',
#  'jishou',
#  'tura',
#  'nemuro',
#  'omboue',
#  'lasem',
#  'bababe',
#  'vao',
#  'marrakesh',
#  'himora',
#  'atasu',
#  'joshimath',
#  'north platte',
#  'quepos',
#  'menongue',
#  'tunxi',
#  'gbadolite',
#  'vitim',
#  'marsabit',
#  'noumea',
#  'henties bay',
#  'rio gallegos',
#  'chumikan',
#  'sao joaquim',
#  'tevriz',
#  'cayenne',
#  'kansk',
#  'comendador',
#  'dubrovka',
#  'tralee',
#  'davila',
#  'novyy urengoy',
#  'loandjili',
#  'obihiro',
#  'kargil',
#  'doha',
#  'sampit',
#  'bagdarin',
#  'calafell',
#  'fevralsk',
#  'moindou',
#  'waterlooville',
#  'maceio',
#  'karauzyak',
#  'kargopol',
#  'potgietersrus',
#  'makakilo city',
#  'madang',
#  'ambunti',
#  'hwange',
#  'schwerin',
#  'kosonsoy',
#  'whitehorse',
#  'aitape',
#  'manta',
#  'porto walter',
#  'loudi',
#  'nushki',
#  'vengurla',
#  'chapais',
#  'kamenka',
#  'benavente',
#  'zaranj',
#  'bintulu',
#  'halifax',
#  'kralendijk',
#  'dasoguz',
#  'bodden town',
#  'houma',
#  'sukhobuzimskoye',
#  'bekhteyevka',
#  'bonthe',
#  'krasne',
#  'riyadh',
#  'longkou',
#  'itupiranga',
#  'surgut',
#  'nichinan',
#  'oxford',
#  'dombarovskiy',
#  'mojo',
#  'tondano',
#  'port hardy',
#  'sisimiut',
#  'atar',
#  'uwayl',
#  'bargal',
#  'bolshegrivskoye',
#  'berezanka',
#  'nyurba',
#  'taltal',
#  'berlevag',
#  'hit',
#  'pangoa',
#  'sedelnikovo',
#  'ntchisi',
#  'ingham',
#  'puerto baquerizo moreno',
#  'visnes',
#  'mumbwa',
#  'chagda',
#  'eskasem',
#  'bunol',
#  'teneguiban',
#  'lata',
#  'warrington',
#  'olden',
#  'nelson bay',
#  'umzimvubu',
#  'maracaibo',
#  'deputatskiy',
#  'jacareacanga',
#  'san juan',
#  'sladkovo',
#  'mazara del vallo',
#  'aksarka',
#  'vicuna',
#  'la union',
#  'taoudenni',
#  'aklavik',
#  'nanakuli',
#  'vanimo',
#  'marystown',
#  'dryden',
#  'rabat',
#  'dicabisagan',
#  'sofiyivka',
#  'kudahuvadhoo',
#  'mackay',
#  'shchelyayur',
#  'nkowakowa',
#  'altar',
#  'tasbuget',
#  'honningsvag',
#  'salalah',
#  'zigos',
#  'verkh-usugli',
#  'linhares',
#  'bereda',
#  'severiano melo',
#  'babaeski',
#  'salinas',
#  'stokmarknes',
#  'kenora',
#  'la rioja',
#  'callaway',
#  'terenos',
#  'nantucket',
#  'fukue',
#  'calama',
#  'voh',
#  'nishihara',
#  'grand centre',
#  'fillira',
#  'silago',
#  'umm kaddadah',
#  'yanchukan',
#  'moose factory',
#  'samarai',
#  'vysokogornyy',
#  'ulladulla',
#  'hohhot',
#  'hammerfest',
#  'geraldton',
#  'miajadas',
#  'turukhansk',
#  'grand forks',
#  'bur gabo',
#  'morant bay',
#  'jilib',
#  'labuhan',
#  'skjervoy',
#  'samana',
#  'wajid',
#  'armacao de pera',
#  'aku',
#  'talcahuano',
#  'pleasanton',
#  'samusu',
#  'semnan',
#  'hay river',
#  'santa catarina',
#  'dillon',
#  'shintomi',
#  'ariquemes',
#  'chiang kham',
#  'tambun',
#  'karamay',
#  'sfantu gheorghe',
#  'salekhard',
#  'ashland',
#  'barcelona',
#  'kintampo',
#  'orlik',
#  'mrirt',
#  'la ronge',
#  'el balyana',
#  'awjilah',
#  'poum',
#  'saint george',
#  'shaoyang',
#  'sergeyevka',
#  'malwan',
#  'karratha',
#  'caruray',
#  'sokoni',
#  'meadow lake',
#  'kuala terengganu',
#  'superior',
#  'sidi ali',
#  'itarema',
#  'alsonemedi',
#  'tautira',
#  'mana',
#  'oranjestad',
#  'faya',
#  'yinchuan',
#  'acarau',
#  'ullapool',
#  'erken-shakhar',
#  'great falls',
#  'mkuranga',
#  'altamira',
#  'yahotyn',
#  'zhizdra',
#  'eureka',
#  'samalaeulu',
#  'quatre cocos',
#  'wasilla',
#  'buchanan',
#  'mabaruma',
#  'brasileia',
#  'umm jarr',
#  'tawkar',
#  'karpuninskiy',
#  'lagoa',
#  'arman',
#  'gravdal',
#  'lasa',
#  'beni suef',
#  'peace river',
#  'batyrevo']

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(5)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | norman wells
# Processing Record 3 of Set 1 | yulara
# Processing Record 4 of Set 1 | khani
# Processing Record 5 of Set 1 | vreed en hoop
# City not found. Skipping...
# Processing Record 6 of Set 1 | barrow
# Processing Record 7 of Set 1 | arraial do cabo
# Processing Record 8 of Set 1 | hasaki
# Processing Record 9 of Set 1 | malanje
# Processing Record 10 of Set 1 | georgetown
# Processing Record 11 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 1 | jiutai
# Processing Record 13 of Set 1 | kushiro
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | faanui
# Processing Record 16 of Set 1 | huilong
# Processing Record 17 of Set 1 | saldanha
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 1 | micheweni
# Processing Record 21 of Set 1 | richards bay
# Processing Record 22 of Set 1 | changtu
# Processing Record 23 of Set 1 | constitucion
# Processing Record 24 of Set 1 | sorland
# Processing Record 25 of Set 1 | saskylakh
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | ketchikan
# Processing Record 28 of Set 1 | limbang
# Processing Record 29 of Set 1 | wulanhaote
# City not found. Skipping...
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | lenine
# Processing Record 32 of Set 1 | hobart
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | bambous virieux
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | mar del plata
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | trinidad
# Processing Record 39 of Set 1 | havre-saint-pierre
# Processing Record 40 of Set 1 | los llanos de aridane
# Processing Record 41 of Set 1 | trenggalek
# Processing Record 42 of Set 1 | sakakah
# Processing Record 43 of Set 1 | pevek
# Processing Record 44 of Set 1 | lompoc
# Processing Record 45 of Set 1 | hilo
# Processing Record 46 of Set 1 | cabedelo
# Processing Record 47 of Set 1 | saint-georges
# Processing Record 48 of Set 1 | great yarmouth
# Processing Record 49 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 50 of Set 1 | wageningen
# Processing Record 1 of Set 2 | severo-kurilsk
# Processing Record 2 of Set 2 | trairi
# Processing Record 3 of Set 2 | toora-khem
# Processing Record 4 of Set 2 | castro
# Processing Record 5 of Set 2 | buta
# Processing Record 6 of Set 2 | shimoda
# Processing Record 7 of Set 2 | ancud
# Processing Record 8 of Set 2 | port elizabeth
# Processing Record 9 of Set 2 | salinopolis
# Processing Record 10 of Set 2 | busselton
# Processing Record 11 of Set 2 | manadhoo
# Processing Record 12 of Set 2 | praya
# Processing Record 13 of Set 2 | pangnirtung
# Processing Record 14 of Set 2 | viytivka
# Processing Record 15 of Set 2 | paamiut
# Processing Record 16 of Set 2 | meulaboh
# Processing Record 17 of Set 2 | lebu
# Processing Record 18 of Set 2 | muros
# Processing Record 19 of Set 2 | shahr-e kord
# Processing Record 20 of Set 2 | kahului
# Processing Record 21 of Set 2 | ormara
# Processing Record 22 of Set 2 | ahome
# Processing Record 23 of Set 2 | ouadda
# Processing Record 24 of Set 2 | kapaa
# Processing Record 25 of Set 2 | ahuimanu
# Processing Record 26 of Set 2 | makueni
# Processing Record 27 of Set 2 | altay
# Processing Record 28 of Set 2 | puerto madero
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | vaini
# Processing Record 31 of Set 2 | karkaralinsk
# City not found. Skipping...
# Processing Record 32 of Set 2 | butaritari
# Processing Record 33 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 2 | dunedin
# Processing Record 35 of Set 2 | pozo colorado
# Processing Record 36 of Set 2 | xichang
# Processing Record 37 of Set 2 | codrington
# Processing Record 38 of Set 2 | ushuaia
# Processing Record 39 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 2 | asyut
# Processing Record 41 of Set 2 | cururupu
# Processing Record 42 of Set 2 | naryan-mar
# Processing Record 43 of Set 2 | mangrol
# Processing Record 44 of Set 2 | saint-augustin
# Processing Record 45 of Set 2 | palu
# Processing Record 46 of Set 2 | jamestown
# Processing Record 47 of Set 2 | teknaf
# Processing Record 48 of Set 2 | waingapu
# Processing Record 49 of Set 2 | nesebar
# Processing Record 50 of Set 2 | victoria point
# Processing Record 1 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 3 | avera
# Processing Record 4 of Set 3 | terney
# Processing Record 5 of Set 3 | solnechnyy
# Processing Record 6 of Set 3 | conde
# Processing Record 7 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 3 | east london
# Processing Record 9 of Set 3 | le port
# Processing Record 10 of Set 3 | dingle
# Processing Record 11 of Set 3 | souillac
# Processing Record 12 of Set 3 | alanya
# Processing Record 13 of Set 3 | honiara
# Processing Record 14 of Set 3 | kaifeng
# Processing Record 15 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 3 | ponta do sol
# Processing Record 17 of Set 3 | cape town
# Processing Record 18 of Set 3 | hermanus
# Processing Record 19 of Set 3 | miranorte
# City not found. Skipping...
# Processing Record 20 of Set 3 | quesnel
# Processing Record 21 of Set 3 | qaanaaq
# Processing Record 22 of Set 3 | port alfred
# Processing Record 23 of Set 3 | burhanpur
# Processing Record 24 of Set 3 | penzance
# Processing Record 25 of Set 3 | vila franca do campo
# Processing Record 26 of Set 3 | key west
# Processing Record 27 of Set 3 | buala
# Processing Record 28 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 3 | nioki
# Processing Record 31 of Set 3 | kizukuri
# Processing Record 32 of Set 3 | bandarbeyla
# Processing Record 33 of Set 3 | kilifi
# Processing Record 34 of Set 3 | upernavik
# Processing Record 35 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 3 | catabola
# Processing Record 37 of Set 3 | pangkalanbuun
# Processing Record 38 of Set 3 | blahodatne
# Processing Record 39 of Set 3 | kimberley
# Processing Record 40 of Set 3 | narsaq
# Processing Record 41 of Set 3 | les cayes
# Processing Record 42 of Set 3 | cabo san lucas
# Processing Record 43 of Set 3 | egvekinot
# Processing Record 44 of Set 3 | amahai
# Processing Record 45 of Set 3 | mao
# Processing Record 46 of Set 3 | okhotsk
# Processing Record 47 of Set 3 | walvis bay
# Processing Record 48 of Set 3 | tiksi
# Processing Record 49 of Set 3 | bluff
# Processing Record 50 of Set 3 | almaznyy
# Processing Record 1 of Set 4 | kruisfontein
# Processing Record 2 of Set 4 | guerrero negro
# Processing Record 3 of Set 4 | kearney
# Processing Record 4 of Set 4 | tynda
# Processing Record 5 of Set 4 | tehachapi
# Processing Record 6 of Set 4 | fort nelson
# Processing Record 7 of Set 4 | ghanzi
# Processing Record 8 of Set 4 | sumbe
# Processing Record 9 of Set 4 | valparaiso
# Processing Record 10 of Set 4 | cockburn town
# Processing Record 11 of Set 4 | bredasdorp
# Processing Record 12 of Set 4 | mahibadhoo
# Processing Record 13 of Set 4 | tasiilaq
# Processing Record 14 of Set 4 | elizabeth city
# Processing Record 15 of Set 4 | longyearbyen
# Processing Record 16 of Set 4 | victor harbor
# Processing Record 17 of Set 4 | kirakira
# Processing Record 18 of Set 4 | plettenberg bay
# Processing Record 19 of Set 4 | fortuna
# Processing Record 20 of Set 4 | kyshtovka
# Processing Record 21 of Set 4 | ambon
# Processing Record 22 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 4 | sioux lookout
# Processing Record 24 of Set 4 | isangel
# Processing Record 25 of Set 4 | japura
# Processing Record 26 of Set 4 | sao joao da barra
# Processing Record 27 of Set 4 | hualmay
# Processing Record 28 of Set 4 | klaksvik
# Processing Record 29 of Set 4 | kodiak
# Processing Record 30 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 4 | rong kwang
# Processing Record 32 of Set 4 | tessalit
# Processing Record 33 of Set 4 | olafsvik
# Processing Record 34 of Set 4 | kavieng
# Processing Record 35 of Set 4 | yellowknife
# Processing Record 36 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 37 of Set 4 | san patricio
# Processing Record 38 of Set 4 | mahebourg
# Processing Record 39 of Set 4 | nikolskoye
# Processing Record 40 of Set 4 | sola
# Processing Record 41 of Set 4 | neiafu
# Processing Record 42 of Set 4 | borborema
# Processing Record 43 of Set 4 | chuy
# Processing Record 44 of Set 4 | hithadhoo
# Processing Record 45 of Set 4 | anadyr
# Processing Record 46 of Set 4 | srandakan
# Processing Record 47 of Set 4 | luderitz
# Processing Record 48 of Set 4 | puerto penasco
# Processing Record 49 of Set 4 | san cristobal
# Processing Record 50 of Set 4 | saint-philippe
# Processing Record 1 of Set 5 | casian
# Processing Record 2 of Set 5 | bethel
# Processing Record 3 of Set 5 | lavrentiya
# Processing Record 4 of Set 5 | iwanai
# Processing Record 5 of Set 5 | port macquarie
# Processing Record 6 of Set 5 | nome
# Processing Record 7 of Set 5 | scarborough
# Processing Record 8 of Set 5 | sabang
# Processing Record 9 of Set 5 | novorudnyy
# Processing Record 10 of Set 5 | kavaratti
# Processing Record 11 of Set 5 | chokurdakh
# Processing Record 12 of Set 5 | talnakh
# Processing Record 13 of Set 5 | xiaolingwei
# Processing Record 14 of Set 5 | pecos
# Processing Record 15 of Set 5 | torbay
# Processing Record 16 of Set 5 | nioro
# Processing Record 17 of Set 5 | yarim
# Processing Record 18 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 5 | santa rosa de viterbo
# Processing Record 20 of Set 5 | wampusirpi
# City not found. Skipping...
# Processing Record 21 of Set 5 | fort-shevchenko
# Processing Record 22 of Set 5 | stabat
# Processing Record 23 of Set 5 | portland
# Processing Record 24 of Set 5 | goderich
# Processing Record 25 of Set 5 | wanxian
# Processing Record 26 of Set 5 | washougal
# Processing Record 27 of Set 5 | pisco
# Processing Record 28 of Set 5 | provideniya
# Processing Record 29 of Set 5 | victoria
# Processing Record 30 of Set 5 | ca mau
# Processing Record 31 of Set 5 | san carlos de bariloche
# Processing Record 32 of Set 5 | stutterheim
# Processing Record 33 of Set 5 | zwedru
# Processing Record 34 of Set 5 | thompson
# Processing Record 35 of Set 5 | litoral del san juan
# City not found. Skipping...
# Processing Record 36 of Set 5 | esperance
# Processing Record 37 of Set 5 | ilulissat
# Processing Record 38 of Set 5 | yumen
# Processing Record 39 of Set 5 | backa topola
# Processing Record 40 of Set 5 | carnarvon
# Processing Record 41 of Set 5 | ardesen
# Processing Record 42 of Set 5 | olinda
# Processing Record 43 of Set 5 | ruda nad moravou
# Processing Record 44 of Set 5 | santa maria
# Processing Record 45 of Set 5 | baisha
# Processing Record 46 of Set 5 | oranjemund
# Processing Record 47 of Set 5 | ayan
# Processing Record 48 of Set 5 | dudinka
# Processing Record 49 of Set 5 | yokadouma
# Processing Record 50 of Set 5 | puerto escondido
# Processing Record 1 of Set 6 | toamasina
# Processing Record 2 of Set 6 | merauke
# Processing Record 3 of Set 6 | coihaique
# Processing Record 4 of Set 6 | gizo
# Processing Record 5 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 6 | laguna
# Processing Record 7 of Set 6 | porvoo
# Processing Record 8 of Set 6 | tateyama
# Processing Record 9 of Set 6 | sitka
# Processing Record 10 of Set 6 | rocha
# Processing Record 11 of Set 6 | alekseyevsk
# Processing Record 12 of Set 6 | grindavik
# Processing Record 13 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 14 of Set 6 | tirumullaivasal
# Processing Record 15 of Set 6 | santa marta
# Processing Record 16 of Set 6 | antalaha
# Processing Record 17 of Set 6 | horadiz
# Processing Record 18 of Set 6 | katsuura
# Processing Record 19 of Set 6 | kaltasy
# Processing Record 20 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 6 | traverse city
# Processing Record 22 of Set 6 | ahipara
# Processing Record 23 of Set 6 | sindor
# Processing Record 24 of Set 6 | upington
# Processing Record 25 of Set 6 | auki
# Processing Record 26 of Set 6 | bathsheba
# Processing Record 27 of Set 6 | tobermory
# Processing Record 28 of Set 6 | vostok
# Processing Record 29 of Set 6 | charters towers
# Processing Record 30 of Set 6 | redlands
# Processing Record 31 of Set 6 | krasnoselkup
# Processing Record 32 of Set 6 | port keats
# Processing Record 33 of Set 6 | bordei verde
# Processing Record 34 of Set 6 | garden city
# Processing Record 35 of Set 6 | kashi
# Processing Record 36 of Set 6 | nadym
# Processing Record 37 of Set 6 | lorengau
# Processing Record 38 of Set 6 | clyde river
# Processing Record 39 of Set 6 | pekan
# Processing Record 40 of Set 6 | vestmannaeyjar
# Processing Record 41 of Set 6 | gambela
# Processing Record 42 of Set 6 | cabo rojo
# Processing Record 43 of Set 6 | lyuban
# Processing Record 44 of Set 6 | yarada
# Processing Record 45 of Set 6 | ewa beach
# Processing Record 46 of Set 6 | cidreira
# Processing Record 47 of Set 6 | kharp
# Processing Record 48 of Set 6 | najran
# Processing Record 49 of Set 6 | tuktoyaktuk
# Processing Record 50 of Set 6 | orgun
# City not found. Skipping...
# Processing Record 1 of Set 7 | launceston
# Processing Record 2 of Set 7 | sinnamary
# Processing Record 3 of Set 7 | bay roberts
# Processing Record 4 of Set 7 | birin
# Processing Record 5 of Set 7 | gornoye loo
# Processing Record 6 of Set 7 | camacha
# Processing Record 7 of Set 7 | balkhash
# Processing Record 8 of Set 7 | sainte-maxime
# Processing Record 9 of Set 7 | kloulklubed
# Processing Record 10 of Set 7 | lucapa
# Processing Record 11 of Set 7 | bronnoysund
# Processing Record 12 of Set 7 | maningrida
# Processing Record 13 of Set 7 | yenagoa
# Processing Record 14 of Set 7 | luena
# Processing Record 15 of Set 7 | lashio
# Processing Record 16 of Set 7 | tuatapere
# Processing Record 17 of Set 7 | korla
# Processing Record 18 of Set 7 | grand gaube
# Processing Record 19 of Set 7 | ambulu
# Processing Record 20 of Set 7 | shiroishi
# Processing Record 21 of Set 7 | fairbanks
# Processing Record 22 of Set 7 | kerema
# Processing Record 23 of Set 7 | manggar
# Processing Record 24 of Set 7 | barra patuca
# Processing Record 25 of Set 7 | hami
# Processing Record 26 of Set 7 | dikson
# Processing Record 27 of Set 7 | kaluga
# Processing Record 28 of Set 7 | half moon bay
# Processing Record 29 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 30 of Set 7 | emerald
# Processing Record 31 of Set 7 | rincon
# Processing Record 32 of Set 7 | sa kaeo
# Processing Record 33 of Set 7 | iqaluit
# Processing Record 34 of Set 7 | douentza
# Processing Record 35 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 36 of Set 7 | saint-denis
# Processing Record 37 of Set 7 | yuli
# Processing Record 38 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 39 of Set 7 | middelburg
# Processing Record 40 of Set 7 | marawi
# Processing Record 41 of Set 7 | adrar
# Processing Record 42 of Set 7 | rusape
# Processing Record 43 of Set 7 | namibe
# Processing Record 44 of Set 7 | sabha
# Processing Record 45 of Set 7 | buraydah
# Processing Record 46 of Set 7 | shache
# Processing Record 47 of Set 7 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 48 of Set 7 | necochea
# Processing Record 49 of Set 7 | ribeira grande
# Processing Record 50 of Set 7 | elat
# Processing Record 1 of Set 8 | tanjong sepat
# City not found. Skipping...
# Processing Record 2 of Set 8 | durango
# Processing Record 3 of Set 8 | niksar
# Processing Record 4 of Set 8 | mezen
# Processing Record 5 of Set 8 | swan hill
# Processing Record 6 of Set 8 | san quintin
# Processing Record 7 of Set 8 | miloslavskoye
# Processing Record 8 of Set 8 | waterloo
# Processing Record 9 of Set 8 | dimitrovgrad
# Processing Record 10 of Set 8 | palmer
# Processing Record 11 of Set 8 | bilma
# Processing Record 12 of Set 8 | uzunkopru
# City not found. Skipping...
# Processing Record 13 of Set 8 | basudebpur
# Processing Record 14 of Set 8 | alice springs
# Processing Record 15 of Set 8 | oga
# Processing Record 16 of Set 8 | hobyo
# Processing Record 17 of Set 8 | oistins
# Processing Record 18 of Set 8 | mount gambier
# Processing Record 19 of Set 8 | americus
# Processing Record 20 of Set 8 | kutum
# Processing Record 21 of Set 8 | vila velha
# Processing Record 22 of Set 8 | kaitangata
# Processing Record 23 of Set 8 | vryburg
# Processing Record 24 of Set 8 | saint-francois
# Processing Record 25 of Set 8 | mount isa
# Processing Record 26 of Set 8 | soyo
# Processing Record 27 of Set 8 | chernyshevskiy
# Processing Record 28 of Set 8 | newport
# Processing Record 29 of Set 8 | pochutla
# Processing Record 30 of Set 8 | umiray
# Processing Record 31 of Set 8 | coquimbo
# Processing Record 32 of Set 8 | skovorodino
# Processing Record 33 of Set 8 | nago
# Processing Record 34 of Set 8 | lebanon
# Processing Record 35 of Set 8 | bosaso
# Processing Record 36 of Set 8 | campoverde
# Processing Record 37 of Set 8 | harper
# Processing Record 38 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 39 of Set 8 | iisalmi
# Processing Record 40 of Set 8 | kuah
# Processing Record 41 of Set 8 | nouadhibou
# Processing Record 42 of Set 8 | rock sound
# Processing Record 43 of Set 8 | porto velho
# Processing Record 44 of Set 8 | nortelandia
# Processing Record 45 of Set 8 | tilichiki
# Processing Record 46 of Set 8 | umm lajj
# Processing Record 47 of Set 8 | puerto carreno
# Processing Record 48 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 49 of Set 8 | yar-sale
# Processing Record 50 of Set 8 | belaya gora
# Processing Record 1 of Set 9 | airai
# Processing Record 2 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 9 | ixtapa
# Processing Record 4 of Set 9 | viedma
# Processing Record 5 of Set 9 | komsomolskiy
# Processing Record 6 of Set 9 | kindersley
# Processing Record 7 of Set 9 | abnub
# Processing Record 8 of Set 9 | aracati
# Processing Record 9 of Set 9 | jinchang
# Processing Record 10 of Set 9 | bitkine
# Processing Record 11 of Set 9 | pizarro
# Processing Record 12 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 13 of Set 9 | vardo
# Processing Record 14 of Set 9 | contamana
# Processing Record 15 of Set 9 | palmas bellas
# Processing Record 16 of Set 9 | boa vista
# Processing Record 17 of Set 9 | tieli
# Processing Record 18 of Set 9 | ciudad ojeda
# Processing Record 19 of Set 9 | canutama
# Processing Record 20 of Set 9 | rundu
# Processing Record 21 of Set 9 | peniche
# Processing Record 22 of Set 9 | asau
# Processing Record 23 of Set 9 | nanortalik
# Processing Record 24 of Set 9 | acapulco
# Processing Record 25 of Set 9 | zhigansk
# Processing Record 26 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 9 | baijiantan
# Processing Record 28 of Set 9 | liberty
# Processing Record 29 of Set 9 | tokonou
# Processing Record 30 of Set 9 | san andres
# Processing Record 31 of Set 9 | goundam
# Processing Record 32 of Set 9 | andreyevo
# Processing Record 33 of Set 9 | ponta delgada
# Processing Record 34 of Set 9 | vuktyl
# Processing Record 35 of Set 9 | khasan
# Processing Record 36 of Set 9 | of
# City not found. Skipping...
# Processing Record 37 of Set 9 | antigonish
# Processing Record 38 of Set 9 | christchurch
# Processing Record 39 of Set 9 | bundibugyo
# Processing Record 40 of Set 9 | namatanai
# Processing Record 41 of Set 9 | khatanga
# Processing Record 42 of Set 9 | novosheshminsk
# Processing Record 43 of Set 9 | nabire
# Processing Record 44 of Set 9 | praia da vitoria
# Processing Record 45 of Set 9 | kathu
# Processing Record 46 of Set 9 | naze
# Processing Record 47 of Set 9 | leningradskiy
# Processing Record 48 of Set 9 | urumqi
# Processing Record 49 of Set 9 | belyy yar
# Processing Record 50 of Set 9 | jalu
# Processing Record 1 of Set 10 | tshane
# Processing Record 2 of Set 10 | nanpara
# Processing Record 3 of Set 10 | berdigestyakh
# Processing Record 4 of Set 10 | vestmanna
# Processing Record 5 of Set 10 | aljezur
# Processing Record 6 of Set 10 | morondava
# Processing Record 7 of Set 10 | san jose
# Processing Record 8 of Set 10 | mareeba
# Processing Record 9 of Set 10 | tual
# Processing Record 10 of Set 10 | springdale
# Processing Record 11 of Set 10 | bengkulu
# Processing Record 12 of Set 10 | hamilton
# Processing Record 13 of Set 10 | kutno
# Processing Record 14 of Set 10 | bastrop
# Processing Record 15 of Set 10 | severodvinsk
# Processing Record 16 of Set 10 | mehamn
# Processing Record 17 of Set 10 | nuuk
# Processing Record 18 of Set 10 | tim
# Processing Record 19 of Set 10 | kindu
# Processing Record 20 of Set 10 | kropotkin
# Processing Record 21 of Set 10 | minuri
# Processing Record 22 of Set 10 | emmen
# Processing Record 23 of Set 10 | jiuquan
# Processing Record 24 of Set 10 | matagami
# Processing Record 25 of Set 10 | kirkwall
# Processing Record 26 of Set 10 | juneau
# Processing Record 27 of Set 10 | cherskiy
# Processing Record 28 of Set 10 | avon park
# Processing Record 29 of Set 10 | gulfport
# Processing Record 30 of Set 10 | praia
# Processing Record 31 of Set 10 | pinheiro machado
# Processing Record 32 of Set 10 | oktyabrskiy
# Processing Record 33 of Set 10 | kansanshi
# Processing Record 34 of Set 10 | port blair
# Processing Record 35 of Set 10 | rawson
# Processing Record 36 of Set 10 | karoi
# Processing Record 37 of Set 10 | peterhead
# Processing Record 38 of Set 10 | touros
# Processing Record 39 of Set 10 | port augusta
# Processing Record 40 of Set 10 | kayiry
# Processing Record 41 of Set 10 | sao filipe
# Processing Record 42 of Set 10 | brae
# Processing Record 43 of Set 10 | westport
# Processing Record 44 of Set 10 | sanary-sur-mer
# Processing Record 45 of Set 10 | mahanje
# Processing Record 46 of Set 10 | aranos
# Processing Record 47 of Set 10 | chivay
# Processing Record 48 of Set 10 | bardiyah
# Processing Record 49 of Set 10 | belmonte
# Processing Record 50 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 1 of Set 11 | antibes
# Processing Record 2 of Set 11 | road town
# Processing Record 3 of Set 11 | moerai
# Processing Record 4 of Set 11 | kirsanov
# Processing Record 5 of Set 11 | west wendover
# Processing Record 6 of Set 11 | beringovskiy
# Processing Record 7 of Set 11 | jishou
# Processing Record 8 of Set 11 | tura
# Processing Record 9 of Set 11 | nemuro
# Processing Record 10 of Set 11 | omboue
# Processing Record 11 of Set 11 | lasem
# Processing Record 12 of Set 11 | bababe
# City not found. Skipping...
# Processing Record 13 of Set 11 | vao
# Processing Record 14 of Set 11 | marrakesh
# Processing Record 15 of Set 11 | himora
# City not found. Skipping...
# Processing Record 16 of Set 11 | atasu
# Processing Record 17 of Set 11 | joshimath
# Processing Record 18 of Set 11 | north platte
# Processing Record 19 of Set 11 | quepos
# Processing Record 20 of Set 11 | menongue
# Processing Record 21 of Set 11 | tunxi
# City not found. Skipping...
# Processing Record 22 of Set 11 | gbadolite
# Processing Record 23 of Set 11 | vitim
# Processing Record 24 of Set 11 | marsabit
# Processing Record 25 of Set 11 | noumea
# Processing Record 26 of Set 11 | henties bay
# Processing Record 27 of Set 11 | rio gallegos
# Processing Record 28 of Set 11 | chumikan
# Processing Record 29 of Set 11 | sao joaquim
# Processing Record 30 of Set 11 | tevriz
# Processing Record 31 of Set 11 | cayenne
# Processing Record 32 of Set 11 | kansk
# Processing Record 33 of Set 11 | comendador
# Processing Record 34 of Set 11 | dubrovka
# Processing Record 35 of Set 11 | tralee
# Processing Record 36 of Set 11 | davila
# Processing Record 37 of Set 11 | novyy urengoy
# Processing Record 38 of Set 11 | loandjili
# Processing Record 39 of Set 11 | obihiro
# Processing Record 40 of Set 11 | kargil
# Processing Record 41 of Set 11 | doha
# Processing Record 42 of Set 11 | sampit
# Processing Record 43 of Set 11 | bagdarin
# Processing Record 44 of Set 11 | calafell
# Processing Record 45 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 46 of Set 11 | moindou
# Processing Record 47 of Set 11 | waterlooville
# Processing Record 48 of Set 11 | maceio
# Processing Record 49 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 50 of Set 11 | kargopol
# Processing Record 1 of Set 12 | potgietersrus
# City not found. Skipping...
# Processing Record 2 of Set 12 | makakilo city
# Processing Record 3 of Set 12 | madang
# Processing Record 4 of Set 12 | ambunti
# Processing Record 5 of Set 12 | hwange
# Processing Record 6 of Set 12 | schwerin
# Processing Record 7 of Set 12 | kosonsoy
# Processing Record 8 of Set 12 | whitehorse
# Processing Record 9 of Set 12 | aitape
# Processing Record 10 of Set 12 | manta
# Processing Record 11 of Set 12 | porto walter
# Processing Record 12 of Set 12 | loudi
# Processing Record 13 of Set 12 | nushki
# Processing Record 14 of Set 12 | vengurla
# Processing Record 15 of Set 12 | chapais
# Processing Record 16 of Set 12 | kamenka
# Processing Record 17 of Set 12 | benavente
# Processing Record 18 of Set 12 | zaranj
# Processing Record 19 of Set 12 | bintulu
# Processing Record 20 of Set 12 | halifax
# Processing Record 21 of Set 12 | kralendijk
# Processing Record 22 of Set 12 | dasoguz
# Processing Record 23 of Set 12 | bodden town
# Processing Record 24 of Set 12 | houma
# Processing Record 25 of Set 12 | sukhobuzimskoye
# Processing Record 26 of Set 12 | bekhteyevka
# Processing Record 27 of Set 12 | bonthe
# Processing Record 28 of Set 12 | krasne
# Processing Record 29 of Set 12 | riyadh
# Processing Record 30 of Set 12 | longkou
# Processing Record 31 of Set 12 | itupiranga
# Processing Record 32 of Set 12 | surgut
# Processing Record 33 of Set 12 | nichinan
# Processing Record 34 of Set 12 | oxford
# Processing Record 35 of Set 12 | dombarovskiy
# Processing Record 36 of Set 12 | mojo
# Processing Record 37 of Set 12 | tondano
# Processing Record 38 of Set 12 | port hardy
# Processing Record 39 of Set 12 | sisimiut
# Processing Record 40 of Set 12 | atar
# Processing Record 41 of Set 12 | uwayl
# City not found. Skipping...
# Processing Record 42 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 12 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 44 of Set 12 | berezanka
# Processing Record 45 of Set 12 | nyurba
# Processing Record 46 of Set 12 | taltal
# Processing Record 47 of Set 12 | berlevag
# Processing Record 48 of Set 12 | hit
# Processing Record 49 of Set 12 | pangoa
# Processing Record 50 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 1 of Set 13 | ntchisi
# Processing Record 2 of Set 13 | ingham
# Processing Record 3 of Set 13 | puerto baquerizo moreno
# Processing Record 4 of Set 13 | visnes
# Processing Record 5 of Set 13 | mumbwa
# Processing Record 6 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 13 | eskasem
# City not found. Skipping...
# Processing Record 8 of Set 13 | bunol
# Processing Record 9 of Set 13 | teneguiban
# City not found. Skipping...
# Processing Record 10 of Set 13 | lata
# Processing Record 11 of Set 13 | warrington
# Processing Record 12 of Set 13 | olden
# Processing Record 13 of Set 13 | nelson bay
# Processing Record 14 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 13 | maracaibo
# Processing Record 16 of Set 13 | deputatskiy
# Processing Record 17 of Set 13 | jacareacanga
# Processing Record 18 of Set 13 | san juan
# Processing Record 19 of Set 13 | sladkovo
# Processing Record 20 of Set 13 | mazara del vallo
# Processing Record 21 of Set 13 | aksarka
# Processing Record 22 of Set 13 | vicuna
# Processing Record 23 of Set 13 | la union
# Processing Record 24 of Set 13 | taoudenni
# Processing Record 25 of Set 13 | aklavik
# Processing Record 26 of Set 13 | nanakuli
# Processing Record 27 of Set 13 | vanimo
# Processing Record 28 of Set 13 | marystown
# Processing Record 29 of Set 13 | dryden
# Processing Record 30 of Set 13 | rabat
# Processing Record 31 of Set 13 | dicabisagan
# Processing Record 32 of Set 13 | sofiyivka
# Processing Record 33 of Set 13 | kudahuvadhoo
# Processing Record 34 of Set 13 | mackay
# Processing Record 35 of Set 13 | shchelyayur
# City not found. Skipping...
# Processing Record 36 of Set 13 | nkowakowa
# Processing Record 37 of Set 13 | altar
# Processing Record 38 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 39 of Set 13 | honningsvag
# Processing Record 40 of Set 13 | salalah
# Processing Record 41 of Set 13 | zigos
# Processing Record 42 of Set 13 | verkh-usugli
# Processing Record 43 of Set 13 | linhares
# Processing Record 44 of Set 13 | bereda
# Processing Record 45 of Set 13 | severiano melo
# Processing Record 46 of Set 13 | babaeski
# Processing Record 47 of Set 13 | salinas
# Processing Record 48 of Set 13 | stokmarknes
# Processing Record 49 of Set 13 | kenora
# Processing Record 50 of Set 13 | la rioja
# Processing Record 1 of Set 14 | callaway
# Processing Record 2 of Set 14 | terenos
# Processing Record 3 of Set 14 | nantucket
# Processing Record 4 of Set 14 | fukue
# Processing Record 5 of Set 14 | calama
# Processing Record 6 of Set 14 | voh
# Processing Record 7 of Set 14 | nishihara
# Processing Record 8 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 9 of Set 14 | fillira
# City not found. Skipping...
# Processing Record 10 of Set 14 | silago
# Processing Record 11 of Set 14 | umm kaddadah
# Processing Record 12 of Set 14 | yanchukan
# City not found. Skipping...
# Processing Record 13 of Set 14 | moose factory
# Processing Record 14 of Set 14 | samarai
# Processing Record 15 of Set 14 | vysokogornyy
# Processing Record 16 of Set 14 | ulladulla
# Processing Record 17 of Set 14 | hohhot
# Processing Record 18 of Set 14 | hammerfest
# Processing Record 19 of Set 14 | geraldton
# Processing Record 20 of Set 14 | miajadas
# Processing Record 21 of Set 14 | turukhansk
# Processing Record 22 of Set 14 | grand forks
# Processing Record 23 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 24 of Set 14 | morant bay
# Processing Record 25 of Set 14 | jilib
# Processing Record 26 of Set 14 | labuhan
# Processing Record 27 of Set 14 | skjervoy
# Processing Record 28 of Set 14 | samana
# Processing Record 29 of Set 14 | wajid
# Processing Record 30 of Set 14 | armacao de pera
# Processing Record 31 of Set 14 | aku
# Processing Record 32 of Set 14 | talcahuano
# Processing Record 33 of Set 14 | pleasanton
# Processing Record 34 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 14 | semnan
# Processing Record 36 of Set 14 | hay river
# Processing Record 37 of Set 14 | santa catarina
# Processing Record 38 of Set 14 | dillon
# Processing Record 39 of Set 14 | shintomi
# Processing Record 40 of Set 14 | ariquemes
# Processing Record 41 of Set 14 | chiang kham
# Processing Record 42 of Set 14 | tambun
# Processing Record 43 of Set 14 | karamay
# City not found. Skipping...
# Processing Record 44 of Set 14 | sfantu gheorghe
# Processing Record 45 of Set 14 | salekhard
# Processing Record 46 of Set 14 | ashland
# Processing Record 47 of Set 14 | barcelona
# Processing Record 48 of Set 14 | kintampo
# Processing Record 49 of Set 14 | orlik
# Processing Record 50 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 1 of Set 15 | la ronge
# Processing Record 2 of Set 15 | el balyana
# City not found. Skipping...
# Processing Record 3 of Set 15 | awjilah
# Processing Record 4 of Set 15 | poum
# Processing Record 5 of Set 15 | saint george
# Processing Record 6 of Set 15 | shaoyang
# Processing Record 7 of Set 15 | sergeyevka
# Processing Record 8 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 9 of Set 15 | karratha
# Processing Record 10 of Set 15 | caruray
# Processing Record 11 of Set 15 | sokoni
# Processing Record 12 of Set 15 | meadow lake
# Processing Record 13 of Set 15 | kuala terengganu
# Processing Record 14 of Set 15 | superior
# Processing Record 15 of Set 15 | sidi ali
# Processing Record 16 of Set 15 | itarema
# Processing Record 17 of Set 15 | alsonemedi
# Processing Record 18 of Set 15 | tautira
# Processing Record 19 of Set 15 | mana
# Processing Record 20 of Set 15 | oranjestad
# Processing Record 21 of Set 15 | faya
# Processing Record 22 of Set 15 | yinchuan
# Processing Record 23 of Set 15 | acarau
# Processing Record 24 of Set 15 | ullapool
# Processing Record 25 of Set 15 | erken-shakhar
# City not found. Skipping...
# Processing Record 26 of Set 15 | great falls
# Processing Record 27 of Set 15 | mkuranga
# Processing Record 28 of Set 15 | altamira
# Processing Record 29 of Set 15 | yahotyn
# Processing Record 30 of Set 15 | zhizdra
# Processing Record 31 of Set 15 | eureka
# Processing Record 32 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 33 of Set 15 | quatre cocos
# Processing Record 34 of Set 15 | wasilla
# Processing Record 35 of Set 15 | buchanan
# Processing Record 36 of Set 15 | mabaruma
# Processing Record 37 of Set 15 | brasileia
# Processing Record 38 of Set 15 | umm jarr
# City not found. Skipping...
# Processing Record 39 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 40 of Set 15 | karpuninskiy
# City not found. Skipping...
# Processing Record 41 of Set 15 | lagoa
# Processing Record 42 of Set 15 | arman
# Processing Record 43 of Set 15 | gravdal
# Processing Record 44 of Set 15 | lasa
# Processing Record 45 of Set 15 | beni suef
# Processing Record 46 of Set 15 | peace river
# Processing Record 47 of Set 15 | batyrevo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Puerto Ayora      EC  -0.7393  -90.3518     73.36        95          65
# 1     Norman Wells      CA  65.2820 -126.8329     53.64        58          20
# 2           Yulara      AU -25.2406  130.9889     62.08        38          86
# 3            Khani      GE  41.9563   42.9566     65.77        88          96
# 4           Barrow      US  71.2906 -156.7887     35.62        87           0
# 5  Arraial Do Cabo      BR -22.9661  -42.0278     75.16        57           0
# 6           Hasaki      JP  35.7333  140.8333     72.00        86         100
# 7          Malanje      AO  -9.5402   16.3410     79.83        24          82
# 8       Georgetown      MY   5.4112  100.3354     84.13        86          40
# 9           Jiutai      CN  44.1525  125.8328     66.54        93          86
#
#    Wind Speed Current Description
# 0        7.00       broken clouds
# 1       10.36          few clouds
# 2        5.84     overcast clouds
# 3        0.98     overcast clouds
# 4       10.36           clear sky
# 5       14.97           clear sky
# 6       13.71     overcast clouds
# 7        2.44       broken clouds
# 8        4.61    scattered clouds
# 9        7.94     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
